# %%
import numpy as np
print('hello numpy')
print(np.array([1,2,3]))
# Out:
# hello numpy
# [1 2 3]

# %%
from matplotlib import pyplot as plt
print('Hello matplotlib')
a = [1, 2, 10, 4]
plt.plot(a)
plt.show()
# Out:
# Hello matplotlib
